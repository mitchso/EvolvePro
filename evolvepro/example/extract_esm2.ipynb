# %%
from evolvepro.plm.extract_esm2 import *

# %%
models = ['esm2_t33_650M_UR50D', 'esm2_t36_3B_UR50D']
# must run this command in the esm_legacy conda environment!
extract_embeddings(model='esm2_t33_650M_UR50D',
                   fasta_files=['outputs/WT.fasta', 'outputs/single_mutants.fasta'],    # make sure to include the wild-type sequence as well
                   output_csv=f'outputs/embeddings_esm2_650m.csv')
# Out:
# Using device: mps
# Loaded model: esm2_t33_650M_UR50D
# Read outputs/WT.fasta with 1 sequences
# Read outputs/single_mutants.fasta with 171 sequences
# Processing 172 sequences in 11 batches of up to 16
# Processing batch 1 of 11 (16 sequences)
#   Writing sequence 1 of 172: WT
#   Writing sequence 2 of 172: M1A
#   Writing sequence 3 of 172: M1C
#   Writing sequence 4 of 172: M1D
#   Writing sequence 5 of 172: M1E
#   Writing sequence 6 of 172: M1F
#   Writing sequence 7 of 172: M1G
#   Writing sequence 8 of 172: M1H
#   Writing sequence 9 of 172: M1I
#   Writing sequence 10 of 172: M1K
#   Writing sequence 11 of 172: M1L
#   Writing sequence 12 of 172: M1N
#   Writing sequence 13 of 172: M1P
#   Writing sequence 14 of 172: M1Q
#   Writing sequence 15 of 172: M1R
#   Writing sequence 16 of 172: M1S
# Processing batch 2 of 11 (16 sequences)
#   Writing sequence 17 of 172: M1T
#   Writing sequence 18 of 172: M1V
#   Writing sequence 19 of 172: M1W
#   Writing sequence 20 of 172: M1Y
# ...
