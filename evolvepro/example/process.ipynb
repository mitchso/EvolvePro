# %%
from evolvepro.src.process import *

# %%
example_sequence = "MASTVKFYW"

# %%
# generate correctly formatted fasta file for the wild-type sequence
wt = generate_wt(wt_sequence=example_sequence, output_file="outputs/WT.fasta")

# %%
# generate fasta file containing all possible single-mutant sequences
single_mutants = generate_single_aa_mutants(wt_sequence=example_sequence, output_file="outputs/single_mutants.fasta")

# %%
interesting_mutants = ['M1C', 'A2Q', 'S3P', 'T4M'] # mutations identified in screening for example

double_mutants = generate_multi_mutants(wt_sequence=example_sequence,
                                        output_file="outputs/double_mutants.fasta",
                                        min_mutations=2,
                                        max_mutations=2,
                                        mutations_list=interesting_mutants)

# %%
doubles_and_triples = generate_multi_mutants(wt_sequence=example_sequence,
                                        output_file="outputs/double_and_triple_mutants.fasta",
                                        min_mutations=2,
                                        max_mutations=3,
                                        mutations_list=interesting_mutants)
